# %%
import guitar_set.annotator as ann

jams_path = '/Users/tom/Music/DataSet/test_set_debleed/eh_BN1-129-Eb_c.jams'

dirpath = '/Users/tom/Music/DataSet/test_set_debleed/eh_BN1-129-Eb_c'
sonify_path = dirpath + '.wav'

# %%
man_jam = ann.csvs_to_jams(dirpath)
man_jam.save(dirpath+'_man.jams')
man_midi = ann.jams_to_midi(man_jam)
ann.sonify(man_midi, dirpath + '_man.wav')

# %%
jam
# Out:
# <JAMS(file_metadata=<FileMetadata(...)>,
#       annotations=[6 annotations],
#       sandbox=<Sandbox(...)>)>

# %%
# Out:
# 0

# %%
# Out:
# 0

# %%
# Out:
# <JAMS(file_metadata=<FileMetadata(...)>,
#       annotations=[6 annotations],
#       sandbox=<Sandbox(...)>)>

# %%
a = jam.search(namespace='pitch_midi')

# %%
a[1]
# Out:
# <Annotation(namespace='pitch_midi',
#             time=0,
#             duration=22.0,
#             annotation_metadata=<AnnotationMetadata(...)>,
#             data=<47 observations>,
#             sandbox=<Sandbox(...)>)>
