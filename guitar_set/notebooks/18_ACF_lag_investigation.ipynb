# %%
cd ../..
# Out:
# /Users/tom/Documents/REPO/guitar-set

# %%
import guitar_set.annotator as ant
import librosa
from IPython.display import Audio
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
jf_funk_s_jam = ant.transcribe_hex('/Users/tom/Music/DataSet/test-set_processed/jf_Funk3-112-C#_s_hex_cln.wav')
# Out:
# (0, 98)
# start:0 end:237
# (2142, 237)
# (1, 98)
# start:237 end:411
# (2142, 174)
# 14.5196700282
# (2.29297052154195, 0.087074829931972797, 9.9429245832744044, 174)
# (2, 98)
# start:411 end:459
# (2142, 48)
# 350.0
# (2.3858503401360545, 0.27283446712018122, 65.038216779692021, 48)
# (3, 98)
# start:459 end:506
# (2142, 47)
# 169.203840487
# (2.6644897959183673, 0.069659863945578326, 52.455105485998786, 47)
# 169.203840487
# (2.8676643990929707, 0.063854875283446688, 52.455105485998786, 47)
# (4, 98)
# start:506 end:538
# (2142, 32)
# 350.0
# (2.9373242630385485, 0.17995464852607723, 65.038216779692021, 32)
# (5, 98)
# start:538 end:633
# (2142, 95)
# 350.0
# (3.1230839002267574, 0.54566893424036289, 65.038216779692021, 95)
# (6, 98)
# start:633 end:687
# (2142, 54)
# 350.0
# (3.6745578231292515, 0.30766439909297061, 65.038216779692021, 54)
# (7, 98)
# start:687 end:727
# (2142, 40)
# 350.0
# (3.9880272108843537, 0.22639455782312945, 65.038216779692021, 40)
# (8, 98)
# ...

# %%
ant.transcribe('/Users/tom/Music/DataSet/test-set_processed/jf_Funk3-112-C#_s_hex_cln/')
# Out:
# (0, 1)
# start:0 end:None
# //anaconda/lib/python2.7/site-packages/librosa/core/time_frequency.py:538: RuntimeWarning: invalid value encountered in log2
#   return 12 * (np.log2(np.atleast_1d(frequencies)) - np.log2(440.0)) + 69
# (3.6281179138321997, 0.14512471655328785, nan, 5853)
# (12.207891156462585, 0.16253968253968232, nan, 5853)
# (12.463310657596372, 0.12190476190476218, nan, 5853)
# (13.003174603174603, 0.12770975056689338, nan, 5853)
# (15.348390022675737, 0.22639455782312901, nan, 5853)
# (21.01986394557823, 0.16834467120181529, nan, 5853)
# (24.404172335600908, 0.18575963718820887, nan, 5853)
# (27.231201814058956, 0.69079365079365118, nan, 5853)
# (33.146485260770973, 0.45859410430838921, nan, 5853)
# jams file generated
# (0, 1)
# start:0 end:None
# jams file generated
# (0, 1)
# start:0 end:None
# (2.9895691609977324, 0.42376417233560115, nan, 5855)
# (9.6478911564625847, 0.22639455782312901, nan, 5855)
# (10.977233560090703, 0.22639455782312901, nan, 5855)
# ...

# %%
import guitar_set.interpreter as itp

# %%
# %matplotlib inline
itp.visualize_jams(jf_funk_s_jam)
plt.show()

# %%
data = itp.sonify_jams(jf_funk_s_jam)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-16-78716f81e1a7> in <module>()
# ----> 1 data = itp.sonify_jams(jf_funk_s_jam)
#
# /Users/tom/Documents/REPO/guitar-set/guitar_set/interpreter.pyc in sonify_jams(jam, fpath, q)
#      35
#      36 def sonify_jams(jam, fpath=None, q=1):
# ---> 37     midi = jams_to_midi(jam, q) # q=1 : with pitchbend
#      38     signal_out = midi.fluidsynth()
#      39     if fpath != None:
#
# /Users/tom/Documents/REPO/guitar-set/guitar_set/interpreter.pyc in jams_to_midi(jam, q)
#      17         midi_ch = pretty_midi.Instrument(program=25)
#      18         for note in anno:
# ---> 19             pitch = int(round(note.value))
#      20             bend_amount = int(round((note.value - pitch) * 4096))
#      21             st = note.time
#
# ValueError: cannot convert float NaN to integer
