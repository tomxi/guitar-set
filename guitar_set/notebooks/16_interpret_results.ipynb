# %%
cd ../..
# Out:
# /Users/tom/Documents/REPO/guitar-set

# %%
folder = '/Users/tom/Music/DataSet/test-set_processed/hb/'

# %%
import glob
jams_list = glob.glob(folder + '*.jams')

# %%
jams_list
# Out:
# ['/Users/tom/Music/DataSet/test-set_processed/hb/jf_Funk3-112-C#_c_hex_cln.jams',
#  '/Users/tom/Music/DataSet/test-set_processed/hb/eh_BN1-129-Eb_c_hex_cln.jams',
#  '/Users/tom/Music/DataSet/test-set_processed/hb/js_SS2-107-Ab_c_hex_cln.jams',
#  '/Users/tom/Music/DataSet/test-set_processed/hb/vl_Jazz2-110-Bb_c_hex_cln.jams',
#  '/Users/tom/Music/DataSet/test-set_processed/hb/jf_Funk3-112-C#_s_hex_cln.jams',
#  '/Users/tom/Music/DataSet/test-set_processed/hb/eh_BN1-129-Eb_s_hex_cln.jams',
#  '/Users/tom/Music/DataSet/test-set_processed/hb/js_SS2-107-Ab_s_hex_cln.jams',
#  '/Users/tom/Music/DataSet/test-set_processed/hb/vl_Jazz2-110-Bb_s_hex_cln.jams']

# %%
import guitar_set.interpreter as itp
import jams
import os

for j in jams_list:
    jam = jams.load(j)
    itp.visualize_jams(jam)
    base_name_list = jam.file_metadata.title.split('_')
    base_name = '_'.join(base_name_list[0:3])
    sonify_outpath = os.path.join(folder, 'sonify/{}_syn.wav'.format(
        base_name))
    itp.sonify_jams(jam, sonify_outpath)
# Out:
# WARNING:root:output_file: /Users/tom/Music/DataSet/test-set_processed/hb/sonify/jf_Funk3-112-C#_c_syn.wav already exists and will be overwritten on build
# WARNING:root:output_file: /Users/tom/Music/DataSet/test-set_processed/hb/sonify/eh_BN1-129-Eb_c_syn.wav already exists and will be overwritten on build
# WARNING:root:output_file: /Users/tom/Music/DataSet/test-set_processed/hb/sonify/js_SS2-107-Ab_c_syn.wav already exists and will be overwritten on build
# WARNING:root:output_file: /Users/tom/Music/DataSet/test-set_processed/hb/sonify/vl_Jazz2-110-Bb_c_syn.wav already exists and will be overwritten on build
# WARNING:root:output_file: /Users/tom/Music/DataSet/test-set_processed/hb/sonify/jf_Funk3-112-C#_s_syn.wav already exists and will be overwritten on build
# WARNING:root:output_file: /Users/tom/Music/DataSet/test-set_processed/hb/sonify/eh_BN1-129-Eb_s_syn.wav already exists and will be overwritten on build
# WARNING:root:output_file: /Users/tom/Music/DataSet/test-set_processed/hb/sonify/js_SS2-107-Ab_s_syn.wav already exists and will be overwritten on build
# WARNING:root:output_file: /Users/tom/Music/DataSet/test-set_processed/hb/sonify/vl_Jazz2-110-Bb_s_syn.wav already exists and will be overwritten on build

# %%
import guitar_set.interpreter as itp
import jams

jam = jams.load(jams_list[0])
jam.file_metadata.title
base_name_list = jam.file_metadata.title.split('_')
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-11-40ff4cd8f636> in <module>()
#       2 import jams
#       3
# ----> 4 jam = jams.load(jams_list[0])
#       5 jam.file_metadata.title
#       6 base_name_list = jam.file_metadata.title.split('_')
#
# IndexError: list index out of range

# %%
base_name_list[0:3]
# Out:
# [u'03', u'SS2-107-Ab', u'solo']
