# %%
folder = '/Users/tom/Music/DataSet/guitar-set_cln/'

# %%
import glob
jams_list = glob.glob(folder + '*.jams')

# %%
import guitar_set.interpreter as itp
import jams
import os

for j in jams_list:
    jam = jams.load(j)
    itp.visualize_jams(jam)
    base_name_list = jam.file_metadata.title.split('_')
    base_name = '_'.join(base_name_list[0:3])
    sonify_outpath = os.path.join(folder, 'sonify/{}_syn.wav'.format(
        base_name))
    itp.sonify_jams(jam, sonify_outpath)
# Out:
# WARNING:root:output_file: /Users/tom/Music/DataSet/guitar-set_cln/sonify/03_SS2-107-Ab_solo_syn.wav already exists and will be overwritten on build
# WARNING:root:output_file: /Users/tom/Music/DataSet/guitar-set_cln/sonify/01_Rock2-85-F_solo_syn.wav already exists and will be overwritten on build
# WARNING:root:output_file: /Users/tom/Music/DataSet/guitar-set_cln/sonify/01_SS2-88-F_comp_syn.wav already exists and will be overwritten on build
# WARNING:root:output_file: /Users/tom/Music/DataSet/guitar-set_cln/sonify/00_Jazz3-137-Eb_solo_syn.wav already exists and will be overwritten on build

# %%
import guitar_set.interpreter as itp
import jams

jam = jams.load(jams_list[0])
jam.file_metadata.title
base_name_list = jam.file_metadata.title.split('_')

# %%
base_name_list[0:3]
# Out:
# [u'03', u'SS2-107-Ab', u'solo']
