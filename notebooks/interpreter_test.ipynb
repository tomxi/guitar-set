# %%
cd ..
# Out:
# /Users/tom/Documents/REPO/guitar-set

# %%
from guitar_set import interpreter as itp
import matplotlib.pyplot as plt
import os
import jams

# %matplotlib inline


def get_all_jamses(a_dir, ext='.jams'):
    return [os.path.join(a_dir, name) for name in os.listdir(a_dir)
            if name.endswith(ext)]

# %%
base_dir = '/Users/tom/Music/DataSet/guitar-set/'
jams_list = get_all_jamses(base_dir, '.jams')
print(len(jams_list))
for jam_path in jams_list:
    print(jam_path)
    jam = jams.load(jam_path)
    out_path = os.path.join(base_dir, os.path.split(jam_path)[1].split('.')[0] + '_syn.wav')
    itp.sonify_jams(jam, out_path, q=0)
    itp.visualize_jams(jam)
# Out:
# 68
# /Users/tom/Music/DataSet/guitar-set/05_SS1-68-E_solo_hex.jams
# /Users/tom/Music/DataSet/guitar-set/03_Rock3-148-C_comp_hex.jams
# /Users/tom/Music/DataSet/guitar-set/03_Rock1-130-A_comp_hex.jams
# /Users/tom/Music/DataSet/guitar-set/01_SS3-98-C_solo_hex.jams
# /Users/tom/Music/DataSet/guitar-set/00_Jazz3-137-Eb_solo_hex.jams
# /Users/tom/Music/DataSet/guitar-set/05_Rock2-85-F_solo_hex.jams
# /Users/tom/Music/DataSet/guitar-set/02_SS3-98-C_comp_hex.jams
# /Users/tom/Music/DataSet/guitar-set/04_Rock3-148-C_solo_hex.jams
# /Users/tom/Music/DataSet/guitar-set/01_Rock2-85-F_solo_hex.jams
# /Users/tom/Music/DataSet/guitar-set/04_Rock1-130-A_solo_hex.jams
# /Users/tom/Music/DataSet/guitar-set/03_Funk3-98-A_solo_hex.jams
# /Users/tom/Music/DataSet/guitar-set/03_SS2-88-F_comp_hex.jams
# /Users/tom/Music/DataSet/guitar-set/02_Funk2-119-G_comp_hex.jams
# /Users/tom/Music/DataSet/guitar-set/00_Rock1-90-C#_comp_hex.jams
# /Users/tom/Music/DataSet/guitar-set/03_BN2-131-B_solo_hex.jams
# /Users/tom/Music/DataSet/guitar-set/01_Rock3-117-Bb_comp_hex.jams
# /Users/tom/Music/DataSet/guitar-set/00_SS2-88-F_solo_hex.jams
# /Users/tom/Music/DataSet/guitar-set/02_BN1-147-Gb_comp_hex.jams
# /Users/tom/Music/DataSet/guitar-set/03_SS2-107-Ab_solo_hex.jams
# /Users/tom/Music/DataSet/guitar-set/03_Jazz1-200-B_solo_hex.jams
# /Users/tom/Music/DataSet/guitar-set/02_Funk3-112-C#_solo_hex.jams
# /Users/tom/Music/DataSet/guitar-set/01_Funk2-108-Eb_solo_hex.jams
# /Users/tom/Music/DataSet/guitar-set/01_Jazz1-130-D_comp_hex.jams
# /Users/tom/Music/DataSet/guitar-set/02_BN1-129-Eb_comp_hex.jams
# /Users/tom/Music/DataSet/guitar-set/03_Jazz2-110-Bb_solo_hex.jams
# /Users/tom/Music/DataSet/guitar-set/04_SS1-68-E_comp_hex.jams
# /Users/tom/Music/DataSet/guitar-set/04_Rock2-85-F_comp_hex.jams
# /Users/tom/Music/DataSet/guitar-set/00_BN2-131-B_solo_hex.jams
# /Users/tom/Music/DataSet/guitar-set/02_Funk1-97-C_solo_hex.jams
# /Users/tom/Music/DataSet/guitar-set/00_Funk1-114-Ab_solo_hex.jams
# /Users/tom/Music/DataSet/guitar-set/00_SS3-98-C_comp_hex.jams
# /Users/tom/Music/DataSet/guitar-set/00_Rock2-85-F_comp_hex.jams
# /Users/tom/Music/DataSet/guitar-set/01_SS2-88-F_comp_hex.jams
# /Users/tom/Music/DataSet/guitar-set/04_Jazz2-110-Bb_solo_hex.jams
# /Users/tom/Music/DataSet/guitar-set/01_Jazz2-187-F#_solo_hex.jams
# /Users/tom/Music/DataSet/guitar-set/02_SS2-88-F_solo_hex.jams
# /Users/tom/Music/DataSet/guitar-set/02_Jazz3-150-C_comp_hex.jams
# /Users/tom/Music/DataSet/guitar-set/02_SS2-107-Ab_comp_hex.jams
# /Users/tom/Music/DataSet/guitar-set/05_Funk3-112-C#_solo_hex.jams
# /Users/tom/Music/DataSet/guitar-set/05_BN3-154-E_comp_hex.jams
# /Users/tom/Music/DataSet/guitar-set/03_Jazz3-137-Eb_comp_hex.jams
# /Users/tom/Music/DataSet/guitar-set/00_Rock1-130-A_solo_hex.jams
# /Users/tom/Music/DataSet/guitar-set/01_BN3-119-G_comp_hex.jams
# /Users/tom/Music/DataSet/guitar-set/00_Rock3-148-C_solo_hex.jams
# /Users/tom/Music/DataSet/guitar-set/03_BN2-166-Ab_solo_hex.jams
# /Users/tom/Music/DataSet/guitar-set/01_BN3-154-E_comp_hex.jams
# /Users/tom/Music/DataSet/guitar-set/04_Rock1-90-C#_comp_hex.jams
# /Users/tom/Music/DataSet/guitar-set/02_Rock3-117-Bb_solo_hex.jams
# /Users/tom/Music/DataSet/guitar-set/03_SS3-84-Bb_solo_hex.jams
# /Users/tom/Music/DataSet/guitar-set/02_SS1-100-C#_comp_hex.jams
# /Users/tom/Music/DataSet/guitar-set/01_Funk2-119-G_solo_hex.jams
# /Users/tom/Music/DataSet/guitar-set/03_Rock1-90-C#_solo_hex.jams
# /Users/tom/Music/DataSet/guitar-set/01_Funk3-112-C#_comp_hex.jams
# /Users/tom/Music/DataSet/guitar-set/02_Funk2-108-Eb_comp_hex.jams
# /Users/tom/Music/DataSet/guitar-set/05_Jazz1-130-D_comp_hex.jams
# /Users/tom/Music/DataSet/guitar-set/00_Jazz2-110-Bb_comp_hex.jams
# /Users/tom/Music/DataSet/guitar-set/00_Jazz1-200-B_comp_hex.jams
# /Users/tom/Music/DataSet/guitar-set/03_Funk1-114-Ab_comp_hex.jams
# /Users/tom/Music/DataSet/guitar-set/02_BN3-154-E_comp_hex.jams
# /Users/tom/Music/DataSet/guitar-set/02_Jazz1-130-D_solo_hex.jams
# /Users/tom/Music/DataSet/guitar-set/04_Funk1-114-Ab_comp_hex.jams
# /Users/tom/Music/DataSet/guitar-set/04_Rock2-142-D_comp_hex.jams
# /Users/tom/Music/DataSet/guitar-set/02_BN2-166-Ab_comp_hex.jams
# /Users/tom/Music/DataSet/guitar-set/02_BN3-119-G_comp_hex.jams
# /Users/tom/Music/DataSet/guitar-set/03_SS1-100-C#_solo_hex.jams
# /Users/tom/Music/DataSet/guitar-set/02_Jazz2-187-F#_comp_hex.jams
# /Users/tom/Music/DataSet/guitar-set/04_SS3-84-Bb_solo_hex.jams
# /Users/tom/Music/DataSet/guitar-set/05_Funk2-108-Eb_comp_hex.jams

# %%
base_dir = '/Users/tom/Music/DataSet/guitar_set/eh'
jams_list = get_all_jamses(base_dir, 'hexc.jams')
for jam_path in jams_list:
    jam = jams.load(jam_path)
    out_path = os.path.join(base_dir, os.path.split(jam_path)[1].split('.')[0] + '_syn.wav')
    itp.sonify_jams(jam, out_path, q=0)
    itp.visualize_jams(jam)

# %%
base_dir = '/Users/tom/Music/DataSet/guitar_set/eh'
jams_list = get_all_jamses(base_dir)
for jam_path in jams_list:
    print(jam_path)
    jam = jams.load(jam_path)
    itp.tablaturize_jams(jam)
    itp.visualize_jams(jam)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-ea13676750c8> in <module>()
#       1 base_dir = '/Users/tom/Music/DataSet/guitar_set/eh'
# ----> 2 jams_list = get_all_jamses(base_dir)
#       3 for jam_path in jams_list:
#       4     print(jam_path)
#       5     jam = jams.load(jam_path)
#
# NameError: name 'get_all_jamses' is not defined
