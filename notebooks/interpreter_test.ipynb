# %%
from guitar_set import interpreter as itp
import matplotlib.pyplot as plt
import os
import jams

# %matplotlib inline

def get_all_jamses(a_dir):
    return [os.path.join(a_dir, name) for name in os.listdir(a_dir)
            if name.endswith('.jams')]



def process_stems(idx):
    print(jams_list[idx])
    jam = jams.load(jams_list[idx])
    itp.visualize_jams(jam)

# %%
base_dir = '/Users/tom/Music/DataSet/guitar_set/aj'
jams_list = get_all_jamses(base_dir)
for i in range(len(jams_list)):
    process_stems(i)
# Out:
# /Users/tom/Music/DataSet/guitar_set/aj/aj_BN1-129-Eb_comp_hexc.jams
# /Users/tom/Music/DataSet/guitar_set/aj/aj_BN1-129-Eb_solo_hexc.jams
# /Users/tom/Music/DataSet/guitar_set/aj/aj_BN1-147-Gb_comp_hexc.jams
# /Users/tom/Music/DataSet/guitar_set/aj/aj_BN1-147-Gb_solo_hexc.jams
# /Users/tom/Music/DataSet/guitar_set/aj/aj_BN2-131-B_comp_hexc.jams
# /Users/tom/Music/DataSet/guitar_set/aj/aj_BN2-131-B_solo_hexc.jams
# /Users/tom/Music/DataSet/guitar_set/aj/aj_BN2-166-Ab_comp_hexc.jams
# /Users/tom/Music/DataSet/guitar_set/aj/aj_BN2-166-Ab_solo_hexc.jams
# /Users/tom/Music/DataSet/guitar_set/aj/aj_BN3-119-G_comp_hexc.jams
# /Users/tom/Music/DataSet/guitar_set/aj/aj_BN3-119-G_solo_hexc.jams
# /Users/tom/Music/DataSet/guitar_set/aj/aj_BN3-154-E_comp_hexc.jams
# /Users/tom/Music/DataSet/guitar_set/aj/aj_BN3-154-E_solo_hexc.jams
# /Users/tom/Music/DataSet/guitar_set/aj/aj_Funk1-114-Ab_comp_hexc.jams
# /Users/tom/Music/DataSet/guitar_set/aj/aj_Funk1-114-Ab_solo_hexc.jams
# ...

# %%
base_dir = '/Users/tom/Music/DataSet/guitar_set/ed'
jams_list = get_all_jamses(base_dir)
for i in range(len(jams_list)):
    process_stems(i)
# Out:
# /Users/tom/Music/DataSet/guitar_set/ed/ed_BN1-129-Eb_comp_hexc.jams
# /Users/tom/Music/DataSet/guitar_set/ed/ed_BN1-129-Eb_solo_hexc.jams
# /Users/tom/Music/DataSet/guitar_set/ed/ed_BN1-147-Gb_comp_hexc.jams
# /Users/tom/Music/DataSet/guitar_set/ed/ed_BN1-147-Gb_solo_hexc.jams
# /Users/tom/Music/DataSet/guitar_set/ed/ed_BN2-131-B_comp_hexc.jams
# /Users/tom/Music/DataSet/guitar_set/ed/ed_BN2-131-B_solo_hexc.jams
# /Users/tom/Music/DataSet/guitar_set/ed/ed_BN2-166-Ab_comp_hexc.jams
# /Users/tom/Music/DataSet/guitar_set/ed/ed_BN2-166-Ab_solo_hexc.jams
# /Users/tom/Music/DataSet/guitar_set/ed/ed_BN3-119-G_comp_hexc.jams
# /Users/tom/Music/DataSet/guitar_set/ed/ed_BN3-119-G_solo_hexc.jams
# /Users/tom/Music/DataSet/guitar_set/ed/ed_BN3-154-E_comp_hexc.jams
# /Users/tom/Music/DataSet/guitar_set/ed/ed_BN3-154-E_solo_hexc.jams
# /Users/tom/Music/DataSet/guitar_set/ed/ed_Funk1-114-Ab_comp_hexc.jams
# /Users/tom/Music/DataSet/guitar_set/ed/ed_Funk1-114-Ab_solo_hexc.jams
# ...

# %%
jams_list[0]
# Out:
# '/Users/tom/Music/DataSet/guitar_set/ed/ed_BN1-129-Eb_comp_hexc.jams'

# %%
base_dir = '/Users/tom/Music/DataSet/guitar_set/ed'
jams_list = get_all_jamses(base_dir)
for jam_path in jams_list:
    jam = jams.load(jam_path)
    out_path = os.path.join(base_dir, os.path.split(jam_path)[1].split('.')[0] + '_syn.wav')
    itp.sonify_jams(jam, out_path, q=0)

# %%
base_dir = '/Users/tom/Music/DataSet/guitar_set/aj'
jams_list = get_all_jamses(base_dir)
for jam_path in jams_list:
    jam = jams.load(jam_path)
    out_path = os.path.join(base_dir, os.path.split(jam_path)[1].split('.')[0] + '_syn.wav')
    itp.sonify_jams(jam, out_path, q=0)

# %%
base_dir = '/Users/tom/Music/DataSet/guitar_set/eh'
jams_list = get_all_jamses(base_dir)
for jam_path in jams_list:
    print(jam_path)
    jam = jams.load(jam_path)
    itp.tablaturize_jams(jam)
    itp.visualize_jams(jam)
# Out:
# /Users/tom/Music/DataSet/guitar_set/eh/02_BN1-129-Eb_comp_hex.jams
# /Users/tom/Music/DataSet/guitar_set/eh/02_BN1-129-Eb_solo_hex.jams
# /Users/tom/Music/DataSet/guitar_set/eh/02_BN1-147-Gb_comp_hex.jams
# /Users/tom/Music/DataSet/guitar_set/eh/02_BN1-147-Gb_solo_hex.jams
# /Users/tom/Music/DataSet/guitar_set/eh/02_BN2-131-B_comp_hex.jams
# /Users/tom/Music/DataSet/guitar_set/eh/02_BN2-131-B_solo_hex.jams
# /Users/tom/Music/DataSet/guitar_set/eh/02_BN2-166-Ab_comp_hex.jams
# /Users/tom/Music/DataSet/guitar_set/eh/02_BN2-166-Ab_solo_hex.jams
# /Users/tom/Music/DataSet/guitar_set/eh/02_BN3-119-G_comp_hex.jams
# /Users/tom/Music/DataSet/guitar_set/eh/02_BN3-119-G_solo_hex.jams
# /Users/tom/Music/DataSet/guitar_set/eh/02_BN3-154-E_comp_hex.jams
# /Users/tom/Music/DataSet/guitar_set/eh/02_BN3-154-E_solo_hex.jams
# /Users/tom/Music/DataSet/guitar_set/eh/02_Funk1-114-Ab_comp_hex.jams
# /Users/tom/Music/DataSet/guitar_set/eh/02_Funk1-114-Ab_solo_hex.jams
# ...
