# %%
from guitar_set import annotator as ann
import matplotlib.pyplot as plt
import os
import jams

# %matplotlib inline

def get_all_jamses(a_dir):
    return [os.path.join(a_dir, name) for name in os.listdir(a_dir)
            if name.endswith('.jams')]



def process_stems(idx):
    print(jams_list[idx])
    jam = jams.load(jams_list[idx])
    ann.visualize_jams(jam)

# %%
base_dir = '/Users/tom/Music/DataSet/test_set_cleaned2'
jams_list = get_all_jamses(base_dir)
for i in range(len(jams_list)):
    process_stems(i)
# Out:
# /Users/tom/Music/DataSet/test_set_cleaned2/eh_BN1-129-Eb_hex_comp_cleaned.jams
# /Users/tom/Music/DataSet/test_set_cleaned2/eh_BN1-129-Eb_hex_solo_cleaned.jams
# /Users/tom/Music/DataSet/test_set_cleaned2/jf_Funk3-112-C#_hex_comp_cleaned.jams
# /Users/tom/Music/DataSet/test_set_cleaned2/jf_Funk3-112-C#_hex_solo_cleaned.jams
# /Users/tom/Music/DataSet/test_set_cleaned2/js_SS2-107-Ab_hex_comp_cleaned.jams
# /Users/tom/Music/DataSet/test_set_cleaned2/js_SS2-107-Ab_hex_solo_cleaned.jams
# /Users/tom/Music/DataSet/test_set_cleaned2/vl_Jazz2-110-Bb_hex_comp_cleaned.jams
# /Users/tom/Music/DataSet/test_set_cleaned2/vl_Jazz2-110-Bb_hex_solo_cleaned.jams

# %%
base_dir = '/Users/tom/Music/DataSet/test_set_annotated1'
jams_list = get_all_jamses(base_dir)
for i in range(len(jams_list)):
    process_stems(i)
# Out:
# /Users/tom/Music/DataSet/test_set_annotated1/eh_BN1-129-Eb_c_man.jams
# /Users/tom/Music/DataSet/test_set_annotated1/eh_BN1-129-Eb_cno_bend_man.jams
# /Users/tom/Music/DataSet/test_set_annotated1/eh_BN1-129-Eb_s_man.jams
# /Users/tom/Music/DataSet/test_set_annotated1/eh_BN1-129-Eb_sno_bend_man.jams
# /Users/tom/Music/DataSet/test_set_annotated1/jf_Funk3-112-C#_c_man.jams
# /Users/tom/Music/DataSet/test_set_annotated1/jf_Funk3-112-C#_cno_bend_man.jams
# /Users/tom/Music/DataSet/test_set_annotated1/jf_Funk3-112-C#_s_man.jams
# /Users/tom/Music/DataSet/test_set_annotated1/jf_Funk3-112-C#_sno_bend_man.jams
# /Users/tom/Music/DataSet/test_set_annotated1/js_SS2-107-Ab_c_man.jams
# /Users/tom/Music/DataSet/test_set_annotated1/js_SS2-107-Ab_cno_bend_man.jams
# /Users/tom/Music/DataSet/test_set_annotated1/js_SS2-107-Ab_s_man.jams
# /Users/tom/Music/DataSet/test_set_annotated1/js_SS2-107-Ab_sno_bend_man.jams
# /Users/tom/Music/DataSet/test_set_annotated1/vl_Jazz2-110-Bb_c_man.jams
# ...
